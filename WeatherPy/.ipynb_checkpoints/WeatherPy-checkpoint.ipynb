# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns
import json
from datetime import datetime as dt
import scipy.stats as st
from scipy.stats import linregress

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
#print(url)

# %%
# Create empty lists to append the API data into lists 
city_name = []
temps = []
humid = []
cloudiness = []
wind_speed = []
lats = []
longs = []
country=[]
date=[]

# Start the call counter 
counter = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    
    response = requests.get(f"{url}&q={city}").json()
    try: 
        city_name.append(response["name"])
        temps.append(response["main"]["temp_max"])
        humid.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record {counter} | {city}")
        #print(f"{url}&q={city}")
        
        # Increase counter by one 
        counter = counter + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 | leningradskiy
# Processing Record 2 | kapaa
# Processing Record 3 | port alfred
# City not found. Skipping...
# Processing Record 4 | taltal
# Processing Record 5 | ponta do sol
# Processing Record 6 | jega
# Processing Record 7 | upernavik
# Processing Record 8 | rikitea
# Processing Record 9 | butaritari
# Processing Record 10 | aksarka
# Processing Record 11 | bengkulu
# Processing Record 12 | torbay
# City not found. Skipping...
# Processing Record 13 | mataura
# Processing Record 14 | ribeira grande
# Processing Record 15 | vardo
# Processing Record 16 | barrow
# Processing Record 17 | hobart
# Processing Record 18 | sao joao da barra
# Processing Record 19 | bredasdorp
# Processing Record 20 | punta arenas
# City not found. Skipping...
# Processing Record 21 | ocampo
# Processing Record 22 | ushuaia
# City not found. Skipping...
# Processing Record 23 | kabompo
# City not found. Skipping...
# Processing Record 24 | sitka
# Processing Record 25 | ilulissat
# Processing Record 26 | chuy
# Processing Record 27 | kysyl-syr
# Processing Record 28 | kendari
# Processing Record 29 | katherine
# Processing Record 30 | streator
# Processing Record 31 | provideniya
# City not found. Skipping...
# Processing Record 32 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 33 | hermanus
# Processing Record 34 | luderitz
# Processing Record 35 | faanui
# Processing Record 36 | avarua
# Processing Record 37 | sao filipe
# Processing Record 38 | payo
# Processing Record 39 | vaini
# Processing Record 40 | villarrica
# Processing Record 41 | cape town
# Processing Record 42 | san andres
# Processing Record 43 | mar del plata
# Processing Record 44 | amravati
# Processing Record 45 | arraial do cabo
# Processing Record 46 | ixtapa
# Processing Record 47 | atuona
# Processing Record 48 | bethel
# Processing Record 49 | laredo
# Processing Record 50 | east london
# Processing Record 51 | evensk
# City not found. Skipping...
# Processing Record 52 | naustdal
# Processing Record 53 | fernie
# Processing Record 54 | mahon
# Processing Record 55 | qaanaaq
# Processing Record 56 | sawtell
# Processing Record 57 | kaitangata
# Processing Record 58 | port lincoln
# Processing Record 59 | assai
# Processing Record 60 | hilo
# Processing Record 61 | chokurdakh
# Processing Record 62 | saldanha
# Processing Record 63 | plettenberg bay
# Processing Record 64 | beinamar
# Processing Record 65 | ketchikan
# Processing Record 66 | severo-kurilsk
# City not found. Skipping...
# Processing Record 67 | fairbanks
# Processing Record 68 | deputatskiy
# Processing Record 69 | port-gentil
# City not found. Skipping...
# Processing Record 70 | shambu
# Processing Record 71 | kjollefjord
# Processing Record 72 | cherskiy
# Processing Record 73 | narsaq
# Processing Record 74 | busselton
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 75 | pacific grove
# Processing Record 76 | puri
# Processing Record 77 | puerto ayora
# Processing Record 78 | tingi
# Processing Record 79 | ranong
# Processing Record 80 | gamba
# Processing Record 81 | bluff
# Processing Record 82 | te anau
# Processing Record 83 | lingao
# Processing Record 84 | arman
# Processing Record 85 | longyearbyen
# Processing Record 86 | jamestown
# Processing Record 87 | pattani
# Processing Record 88 | nabire
# Processing Record 89 | comodoro rivadavia
# Processing Record 90 | broken hill
# Processing Record 91 | port macquarie
# Processing Record 92 | carnarvon
# Processing Record 93 | tuatapere
# Processing Record 94 | san patricio
# Processing Record 95 | aklavik
# Processing Record 96 | kruisfontein
# Processing Record 97 | kishi
# Processing Record 98 | mengcheng
# Processing Record 99 | victoria
# Processing Record 100 | malanje
# Processing Record 101 | albany
# Processing Record 102 | saint-philippe
# Processing Record 103 | georgetown
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 104 | los llanos de aridane
# City not found. Skipping...
# Processing Record 105 | blagoveshchenka
# Processing Record 106 | crotone
# Processing Record 107 | new norfolk
# Processing Record 108 | constitucion
# Processing Record 109 | maxixe
# Processing Record 110 | burla
# Processing Record 111 | college
# Processing Record 112 | cordoba
# Processing Record 113 | mitsamiouli
# Processing Record 114 | fort-shevchenko
# City not found. Skipping...
# Processing Record 115 | paciran
# Processing Record 116 | newport
# Processing Record 117 | maarianhamina
# Processing Record 118 | aswan
# Processing Record 119 | mlonggo
# Processing Record 120 | kyshtovka
# Processing Record 121 | yellowknife
# Processing Record 122 | bambanglipuro
# Processing Record 123 | magalia
# City not found. Skipping...
# Processing Record 124 | sur
# Processing Record 125 | juba
# Processing Record 126 | valdivia
# Processing Record 127 | guanica
# Processing Record 128 | alice springs
# Processing Record 129 | lubao
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 130 | kahului
# Processing Record 131 | les cayes
# Processing Record 132 | ostrovnoy
# Processing Record 133 | vaitape
# Processing Record 134 | ararat
# Processing Record 135 | touros
# Processing Record 136 | ocos
# Processing Record 137 | talnakh
# Processing Record 138 | wamba
# Processing Record 139 | saquarema
# Processing Record 140 | mogadishu
# Processing Record 141 | pisco
# Processing Record 142 | soyo
# Processing Record 143 | svidnik
# Processing Record 144 | shizunai
# Processing Record 145 | mount isa
# Processing Record 146 | avera
# Processing Record 147 | inta
# Processing Record 148 | lagoa
# Processing Record 149 | vanimo
# Processing Record 150 | saurimo
# Processing Record 151 | malabo
# Processing Record 152 | katsuura
# Processing Record 153 | savelugu
# Processing Record 154 | dzaoudzi
# Processing Record 155 | marsa matruh
# Processing Record 156 | mahebourg
# Processing Record 157 | hokitika
# Processing Record 158 | yeniseysk
# Processing Record 159 | kodiak
# Processing Record 160 | meulaboh
# Processing Record 161 | nioro
# City not found. Skipping...
# Processing Record 162 | brigantine
# Processing Record 163 | kushiro
# Processing Record 164 | batagay-alyta
# Processing Record 165 | dikson
# Processing Record 166 | hithadhoo
# Processing Record 167 | aldergrove
# Processing Record 168 | hami
# Processing Record 169 | copiapo
# Processing Record 170 | erzin
# Processing Record 171 | predivinsk
# Processing Record 172 | northam
# Processing Record 173 | mugur-aksy
# Processing Record 174 | dongning
# Processing Record 175 | sibolga
# Processing Record 176 | alindao
# Processing Record 177 | gat
# Processing Record 178 | tiksi
# Processing Record 179 | arlit
# Processing Record 180 | goure
# Processing Record 181 | oranjemund
# Processing Record 182 | tuy hoa
# Processing Record 183 | vestmannaeyjar
# Processing Record 184 | khatanga
# Processing Record 185 | ninotsminda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 186 | santa cruz
# Processing Record 187 | zeya
# Processing Record 188 | lokosovo
# Processing Record 189 | oistins
# Processing Record 190 | hambantota
# Processing Record 191 | monywa
# Processing Record 192 | saint george
# City not found. Skipping...
# Processing Record 193 | lebu
# Processing Record 194 | pickerington
# Processing Record 195 | kollam
# Processing Record 196 | srednekolymsk
# Processing Record 197 | palmer
# Processing Record 198 | honiara
# City not found. Skipping...
# Processing Record 199 | porterville
# Processing Record 200 | morondava
# City not found. Skipping...
# Processing Record 201 | korla
# Processing Record 202 | castro
# City not found. Skipping...
# Processing Record 203 | camacha
# Processing Record 204 | goundi
# Processing Record 205 | djambala
# Processing Record 206 | manoel urbano
# Processing Record 207 | natal
# Processing Record 208 | half moon bay
# Processing Record 209 | taos
# Processing Record 210 | de aar
# Processing Record 211 | nikolskoye
# Processing Record 212 | craig
# Processing Record 213 | moramanga
# Processing Record 214 | lensk
# Processing Record 215 | westerland
# Processing Record 216 | shenzhen
# Processing Record 217 | vao
# Processing Record 218 | aberdeen
# Processing Record 219 | obo
# Processing Record 220 | port augusta
# Processing Record 221 | taree
# Processing Record 222 | zhangye
# Processing Record 223 | grand-lahou
# Processing Record 224 | dunedin
# Processing Record 225 | lekoni
# Processing Record 226 | leh
# Processing Record 227 | havelock
# Processing Record 228 | haines junction
# Processing Record 229 | caravelas
# Processing Record 230 | kapit
# Processing Record 231 | kalmunai
# Processing Record 232 | tura
# Processing Record 233 | lasem
# Processing Record 234 | north bend
# Processing Record 235 | sioux falls
# Processing Record 236 | hofn
# Processing Record 237 | zhigansk
# Processing Record 238 | kayerkan
# Processing Record 239 | shibetsu
# Processing Record 240 | bac lieu
# Processing Record 241 | ettingen
# Processing Record 242 | opuwo
# Processing Record 243 | zhangzhou
# Processing Record 244 | pozo colorado
# Processing Record 245 | grand gaube
# Processing Record 246 | matara
# Processing Record 247 | kaeo
# Processing Record 248 | vila franca do campo
# Processing Record 249 | nyurba
# Processing Record 250 | airai
# City not found. Skipping...
# Processing Record 251 | severobaykalsk
# Processing Record 252 | bubaque
# Processing Record 253 | novikovo
# Processing Record 254 | ancud
# Processing Record 255 | fecamp
# Processing Record 256 | namibe
# Processing Record 257 | port hardy
# Processing Record 258 | occhiobello
# Processing Record 259 | develi
# Processing Record 260 | norwich
# Processing Record 261 | abu dhabi
# Processing Record 262 | dingle
# Processing Record 263 | bereda
# Processing Record 264 | thompson
# Processing Record 265 | oudtshoorn
# Processing Record 266 | awjilah
# Processing Record 267 | hamina
# Processing Record 268 | abonnema
# Processing Record 269 | warrington
# Processing Record 270 | axim
# Processing Record 271 | areosa
# Processing Record 272 | riyadh
# Processing Record 273 | borger
# Processing Record 274 | bukachacha
# Processing Record 275 | cidreira
# Processing Record 276 | richards bay
# Processing Record 277 | husavik
# Processing Record 278 | bathsheba
# Processing Record 279 | clyde river
# Processing Record 280 | wilmington island
# Processing Record 281 | bawku
# Processing Record 282 | atar
# Processing Record 283 | santa isabel do rio negro
# Processing Record 284 | esperance
# Processing Record 285 | campbellton
# Processing Record 286 | teahupoo
# Processing Record 287 | nanyang
# Processing Record 288 | tianpeng
# Processing Record 289 | pangnirtung
# Processing Record 290 | nome
# Processing Record 291 | kambove
# Processing Record 292 | port-cartier
# Processing Record 293 | saint-pierre
# City not found. Skipping...
# Processing Record 294 | jalu
# City not found. Skipping...
# Processing Record 295 | iqaluit
# Processing Record 296 | tasiilaq
# Processing Record 297 | pevek
# Processing Record 298 | alofi
# Processing Record 299 | charters towers
# Processing Record 300 | beringovskiy
# Processing Record 301 | pimentel
# Processing Record 302 | la paz
# Processing Record 303 | mwense
# Processing Record 304 | aginskoye
# Processing Record 305 | vlore
# City not found. Skipping...
# Processing Record 306 | kitimat
# Processing Record 307 | pyapon
# City not found. Skipping...
# Processing Record 308 | ambilobe
# Processing Record 309 | jadu
# Processing Record 310 | issenye
# Processing Record 311 | nunchia
# Processing Record 312 | shenjiamen
# Processing Record 313 | codrington
# Processing Record 314 | san vicente
# Processing Record 315 | rawson
# Processing Record 316 | perth
# Processing Record 317 | partizanskoye
# City not found. Skipping...
# Processing Record 318 | vostok
# Processing Record 319 | pervomayskoye
# Processing Record 320 | kota belud
# Processing Record 321 | port elizabeth
# Processing Record 322 | katubao
# Processing Record 323 | havoysund
# Processing Record 324 | westport
# Processing Record 325 | am timan
# Processing Record 326 | rio blanco
# Processing Record 327 | impfondo
# Processing Record 328 | jinchang
# City not found. Skipping...
# Processing Record 329 | coahuayana
# Processing Record 330 | kavaratti
# Processing Record 331 | la sarre
# Processing Record 332 | hovd
# Processing Record 333 | tapes
# Processing Record 334 | waingapu
# Processing Record 335 | cockburn town
# Processing Record 336 | wuhu
# Processing Record 337 | kerman
# Processing Record 338 | wakkanai
# Processing Record 339 | itarema
# Processing Record 340 | porto santo
# Processing Record 341 | mercaderes
# Processing Record 342 | kushmurun
# Processing Record 343 | granard
# Processing Record 344 | lompoc
# Processing Record 345 | hualmay
# Processing Record 346 | portland
# Processing Record 347 | wajid
# Processing Record 348 | dong hoi
# Processing Record 349 | newcastle
# Processing Record 350 | shahr-e babak
# Processing Record 351 | bambous virieux
# City not found. Skipping...
# Processing Record 352 | kavieng
# Processing Record 353 | lata
# Processing Record 354 | cabo san lucas
# Processing Record 355 | gogrial
# Processing Record 356 | itoman
# Processing Record 357 | cabedelo
# Processing Record 358 | gongzhuling
# Processing Record 359 | taksimo
# Processing Record 360 | roald
# Processing Record 361 | las vegas
# Processing Record 362 | nanning
# Processing Record 363 | causapscal
# Processing Record 364 | la peca
# Processing Record 365 | saskylakh
# Processing Record 366 | winnemucca
# Processing Record 367 | henties bay
# Processing Record 368 | lavrentiya
# City not found. Skipping...
# Processing Record 369 | lisakovsk
# Processing Record 370 | pathein
# City not found. Skipping...
# Processing Record 371 | buraydah
# Processing Record 372 | litovko
# Processing Record 373 | balykshi
# Processing Record 374 | jose de freitas
# Processing Record 375 | sorong
# Processing Record 376 | guarapari
# Processing Record 377 | nemuro
# Processing Record 378 | blackwater
# Processing Record 379 | geraldton
# Processing Record 380 | povenets
# Processing Record 381 | komsomolskiy
# Processing Record 382 | umm kaddadah
# Processing Record 383 | fortuna
# Processing Record 384 | sorland
# Processing Record 385 | salamina
# City not found. Skipping...
# Processing Record 386 | pathalgaon
# Processing Record 387 | tacuarembo
# Processing Record 388 | moosomin
# Processing Record 389 | nanortalik
# Processing Record 390 | flinders
# Processing Record 391 | guayaramerin
# Processing Record 392 | port keats
# Processing Record 393 | labuhan
# City not found. Skipping...
# Processing Record 394 | chaman
# Processing Record 395 | mnogovershinnyy
# Processing Record 396 | port hedland
# Processing Record 397 | lagoa formosa
# City not found. Skipping...
# Processing Record 398 | siva
# Processing Record 399 | marau
# Processing Record 400 | agdas
# Processing Record 401 | naze
# Processing Record 402 | the valley
# Processing Record 403 | adrar
# Processing Record 404 | yulara
# Processing Record 405 | werda
# Processing Record 406 | west wendover
# Processing Record 407 | manzhouli
# Processing Record 408 | cortes
# Processing Record 409 | noshiro
# Processing Record 410 | quievrain
# Processing Record 411 | dukat
# Processing Record 412 | medveditskiy
# Processing Record 413 | andros town
# Processing Record 414 | baraki barak
# Processing Record 415 | buala
# Processing Record 416 | liverpool
# City not found. Skipping...
# Processing Record 417 | bowen
# Processing Record 418 | mareeba
# Processing Record 419 | ulaanbaatar
# Processing Record 420 | sherman
# Processing Record 421 | aquidauana
# Processing Record 422 | mae sai
# Processing Record 423 | maposeni
# Processing Record 424 | kurchum
# Processing Record 425 | verkhoyansk
# Processing Record 426 | conakry
# Processing Record 427 | kapuskasing
# Processing Record 428 | iranshahr
# Processing Record 429 | namatanai
# Processing Record 430 | roswell
# Processing Record 431 | pak phanang
# Processing Record 432 | dahuk
# Processing Record 433 | rakiv lis
# Processing Record 434 | hasaki
# Processing Record 435 | hitoyoshi
# Processing Record 436 | knysna
# Processing Record 437 | wahlern
# Processing Record 438 | anqing
# Processing Record 439 | sungaipenuh
# Processing Record 440 | cap malheureux
# Processing Record 441 | dakar
# Processing Record 442 | mocuba
# City not found. Skipping...
# Processing Record 443 | miles city
# Processing Record 444 | vila velha
# City not found. Skipping...
# Processing Record 445 | antofagasta
# Processing Record 446 | poum
# Processing Record 447 | guarda
# Processing Record 448 | moose factory
# City not found. Skipping...
# Processing Record 449 | tecoanapa
# Processing Record 450 | constantine
# Processing Record 451 | bandundu
# Processing Record 452 | tukrah
# Processing Record 453 | mersing
# Processing Record 454 | lorengau
# Processing Record 455 | coihaique
# Processing Record 456 | bjornevatn
# Processing Record 457 | klaksvik
# Processing Record 458 | kulhudhuffushi
# Processing Record 459 | maceio
# Processing Record 460 | unity
# Processing Record 461 | cairns
# Processing Record 462 | quetigny
# Processing Record 463 | mpika
# Processing Record 464 | okhotsk
# Processing Record 465 | nelson bay
# Processing Record 466 | ahipara
# Processing Record 467 | san pedro de macoris
# Processing Record 468 | kiruna
# Processing Record 469 | tefe
# Processing Record 470 | zapotitlan
# Processing Record 471 | sidi ali
# Processing Record 472 | marsh harbour
# Processing Record 473 | rokytne
# Processing Record 474 | severo-yeniseyskiy
# Processing Record 475 | segou
# Processing Record 476 | duku
# Processing Record 477 | bayan
# Processing Record 478 | vondrozo
# Processing Record 479 | kamogata
# Processing Record 480 | iquique
# Processing Record 481 | ayorou
# Processing Record 482 | petropavlovsk-kamchatskiy
# Processing Record 483 | ponezhukay
# Processing Record 484 | tyukhtet
# Processing Record 485 | ilhabela
# Processing Record 486 | luba
# Processing Record 487 | hefei
# Processing Record 488 | mehamn
# Processing Record 489 | apt
# Processing Record 490 | lufilufi
# Processing Record 491 | tilichiki
# Processing Record 492 | laje
# Processing Record 493 | orange
# Processing Record 494 | ponta delgada
# Processing Record 495 | necochea
# Processing Record 496 | phuket
# Processing Record 497 | ciudad bolivar
# Processing Record 498 | valleyview
# Processing Record 499 | aykhal
# Processing Record 500 | porbandar
# Processing Record 501 | sola
# Processing Record 502 | fort nelson
# Processing Record 503 | doha
# Processing Record 504 | athy
# Processing Record 505 | storforshei
# Processing Record 506 | salalah
# Processing Record 507 | prince rupert
# Processing Record 508 | kuybyshevo
# Processing Record 509 | oksfjord
# City not found. Skipping...
# Processing Record 510 | inuvik
# Processing Record 511 | rocha
# Processing Record 512 | lima
# Processing Record 513 | aranos
# Processing Record 514 | saint-francois
# Processing Record 515 | tomball
# Processing Record 516 | praia da vitoria
# Processing Record 517 | laguna
# Processing Record 518 | bandarbeyla
# Processing Record 519 | slave lake
# Processing Record 520 | ulladulla
# Processing Record 521 | kirakira
# Processing Record 522 | chifeng
# Processing Record 523 | north myrtle beach
# Processing Record 524 | alta floresta
# Processing Record 525 | mbini
# Processing Record 526 | torit
# Processing Record 527 | victor harbor
# City not found. Skipping...
# Processing Record 528 | buenos aires
# Processing Record 529 | montego bay
# Processing Record 530 | spirit river
# City not found. Skipping...
# Processing Record 531 | upata
# Processing Record 532 | villeneuve-les-avignon
# Processing Record 533 | atherton
# Processing Record 534 | okahandja
# City not found. Skipping...
# Processing Record 535 | sabang
# Processing Record 536 | namioka
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 537 | souillac
# Processing Record 538 | mount gambier
# Processing Record 539 | jackson
# Processing Record 540 | peringat
# Processing Record 541 | puerto baquerizo moreno
# Processing Record 542 | norman wells
# Processing Record 543 | chateaubelair
# Processing Record 544 | rajgarh
# Processing Record 545 | ust-maya
# Processing Record 546 | margate
# Processing Record 547 | tagusao
# Processing Record 548 | rio grande
# Processing Record 549 | morros
# Processing Record 550 | mulege
# Processing Record 551 | la asuncion
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 552 | valparaiso
# Processing Record 553 | erenhot
# Processing Record 554 | khasan
# Processing Record 555 | ganganagar

# %% [markdown]
# ### Converting Raw Data to DataFrame
# * Exporting the city data into a .csv.
# * Displaying the DataFrame

# %%
#create dataframe
city_weather_df = pd.DataFrame({
    "City" : city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humid,
    "Latitude": lats,
    "Longitude" :longs,
    "Max Temp": temps,
    "Wind Speed": wind_speed,
})
city_weather_df.count()
# Out:
# City          555
# Cloudiness    555
# Country       555
# Date          555
# Humidity      555
# Latitude      555
# Longitude     555
# Max Temp      555
# Wind Speed    555
# dtype: int64

# %%
# save it to CSV file
city_weather_df.to_csv("data/CityData.csv")

# Display data frame head 
city_weather_df.head(10)
# Out:
#             City  Cloudiness Country        Date  Humidity  Latitude  \
# 0  Leningradskiy         100      RU  1605046506        96     69.38
# 1          Kapaa          40      US  1605046349        74     22.08
# 2    Port Alfred          94      ZA  1605046509        77    -33.59
# 3         Taltal          25      CL  1605046220        67    -25.40
# 4   Ponta do Sol          75      PT  1605046512        72     32.67
# 5           Jega          31      NG  1605046513        26     12.22
# 6      Upernavik         100      GL  1605046515        90     72.79
# 7        Rikitea           0      PF  1605046517        79    -23.12
# 8     Butaritari          36      KI  1605046518        78      3.07
# 9        Aksarka          62      RU  1605046520        93     66.56
#
#    Longitude  Max Temp  Wind Speed
# 0     178.42     24.84       17.60
# 1    -159.32     82.40       18.34
# 2      26.89     60.21        7.31
# 3     -70.48     62.13        5.08
# 4     -17.10     68.00        2.24
# 5       4.38     78.04        8.08
# 6     -56.15     10.53        5.57
# 7    -134.97     74.07       17.98
# 8     172.79     82.04        8.77
# 9      67.80      7.56        5.55

# %%
# Calculate current date from datetime library
current_date = dt.now().strftime("(%m/%d/%Y)")
print(current_date)
# Out:
# (11/10/2020)

# %% [markdown]
# ### Plotting the Data
# * Used proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Saved the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot Latitude vs Max Temp
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Max Temp"], marker="o",s=30,facecolors="green",edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs. Max Temperature" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Max Temperature(F)",fontsize = 13)
sns.set_style('darkgrid')
plt.ylim(min(city_weather_df["Max Temp"])-20, max(city_weather_df["Max Temp"])+20)
plt.grid(True)

#save the figure
plt.savefig("Images/Temperature_in_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showcase the relationship between Latitude at x-axis vs Max Temperature (F) at the y-axis. This result indicates that there is a higher temrature for the cities that found near to the equater (Latitude 0),however when you go farther from the equator towrads to the north and south the temprature will decrease.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot of Humidity vs latitude
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Humidity"], marker="o",s=30, facecolors="green",edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs Humidity" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Humidity (%)",fontsize = 13)
plt.xlim(-80, 90)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Humidity_in_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot displayed the relationship between Humidity (%) vs. Latitude. From the result we can infer that humidity is fairly distributed troughout the plot, so we can say that high humidity occer for both cities found farther or near to the equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot of Latitude Vs Cloudiness
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Cloudiness"], marker="o", facecolors="green", edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs Cloudiness" + " " + current_date ,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Cloudiness (%)",fontsize = 13)
plt.ylim(min(city_weather_df["Cloudiness"])-10, max(city_weather_df["Cloudiness"])+10)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Cloudiness_In_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showed the relationship between the cities cloudness, and latitude. From this result we can tell that the data is evenly distributed, and there is no difference in Cloudiness when the cities farther or nearer to the equater(Latitude 0).

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot of latitude vs wind speed
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Wind Speed"],marker="o",s=30, facecolors="green", edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs Wind Speed" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Wind Speed (mph)",fontsize = 13)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Wind_Speed_In_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showed the relationship between wind speed (mph), and latitude. The plot displayed the lower wind speed when the cities closer to the equater (latitude 0) and somehow the wind speed increases for the cities farther from the equator (Latitude 60).

# %%
#Create a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept

# Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
    fig1, ax1 = plt.subplots(figsize=(10, 6))
    plt.scatter(x_values,y_values,color = 'purple',edgecolor = "black",alpha = 0.80, linewidths = 1)

# Add labels and title to plot
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} Linear Regression {current_date}",fontsize = 16)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    plt.grid(True)

# Annotate linear regression
    plt.annotate(line_eq,(10, 50),fontsize=20,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction', horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-30, 60),fontsize=20,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-40, 10),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
# Print correlation and r square value
    print(f"The correlation between both factors is : {round(st.pearsonr(x_values, y_values)[0],2)}")
    print(f"The r-squared is: {round(rvalue**2,3)}")

    return plt.plot(x_values,regress_values,"r-")

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere = city_weather_df.loc[city_weather_df["Latitude"] >= 0]
southern_hemisphere = city_weather_df.loc[city_weather_df["Latitude"] < 0]

# %% [markdown]
# #### Northern Hemisphere - Max Temp(F) vs. Latitude Linear Regression

# %%
#linear regression model for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Max Temp']

createLinearRegressionPlot(x_values, y_values, "Latitude", "Max Temp(F)","Northern",(0, 0))

plt.savefig("Images/Northern_Hemisphere_Max_Temp_vs._Latitude_Linear_Regression.png", bbox_inches = "tight")
plt.show()
# Out:
# The correlation between both factors is : -0.85
# The r-squared is: 0.73

# %% [markdown]
# #### The above scattered graph is a linear regression model between Maximum Temperature and Latitude for Northern Hemisphere cities. The result from the data showed that there is a strong negative correlation between Maximum Temperature and Latitude which means when we go farther away from the equater(latitude 0) the maximum Temperature (F) will decrease.

# %% [markdown]
# #### Southern Hemisphere - Max Temp(F) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Max Temp']

createLinearRegressionPlot(x_values, y_values, "Latitude", "Max Temp(F)", "Southern",(-30, 60))

plt.savefig("Images/Southern_Hemisphere_Max_Temp_vs._Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.62
# The r-squared is: 0.384

# %% [markdown]
# #### The above scattered graph is a linear regression model between Maximum Temperature and Latitude for Southern Hemisphere cities. The result from the data showed that there is a moderate positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humidity (northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Humidity']

createLinearRegressionPlot(x_values, y_values,"Latitude", "Humidity (%)", "Northern",(40, 20))

plt.savefig("Images/Northern_Hemisphere_Humidity_vs._Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.31
# The r-squared is: 0.096

# %% [markdown]
# #### The above plot is a linear regression model between Humidity (%) and Latitude for Northern Hemisphere cities. The result from the data showed that there is a moderate positive correlation between Humidity (%) and Latitude in the Northern Hemisphere cities.¶

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humidity (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Humidity']

createLinearRegressionPlot(x_values, y_values,"Latitude", "Humidity (%)", "Sorthern",(40, 20))

plt.savefig("Images/Southern_Hemisphere_Humidity_vs._Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.05
# The r-squared is: 0.0

# %% [markdown]
# #### The above plot is a linear regression model between Humidity (%) and Latitude for Southern Hemisphere cities. The result from the data showed that there is a very week positive correlation between Humidity (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

plt.savefig("Images/Northern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.19
# The r-squared is: 0.04

# %% [markdown]
# #### The above plot is a linear regression model between Cloudiness (%) and Latitude for Northern_Hemisphere cities. The result from the data showed that there is a week positive correlation between Cloudiness (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("Images/Southern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.32
# The r-squared is: 0.1

# %% [markdown]
# #### The above plot is a linear regression model between Cloudiness (%) and for Southern Hemisphere cities. The result from the data showed that there is a week positive correlation between Cloudiness (%) and Latitude in the Southern Hemisphere cities.¶

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("Images/Northern_Hemisphere_Wind_Speed_Latitude_Lin.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.15
# The r-squared is: 0.02

# %% [markdown]
# #### The above plot is a linear regression model between Wind Speed (mph), and latitude for Northern Hemisphere cities. The result from the data showed that there is a very week positive correlation between Wind Speed (mph (%) and Latitude in the Northern Hemisphere cities.

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25))
plt.savefig("Images/Southern_Hemisphere_Wind_Speed_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : -0.07
# The r-squared is: 0.0

# %% [markdown]
# #### The above plot is a linear regression model between Wind Speed (mph), and latitude for Southern Hemisphere. The result from the data showed that there is a very week negative correlation between Wind Speed (mph (%) and Latitude in the Southern Hemisphere cities.
