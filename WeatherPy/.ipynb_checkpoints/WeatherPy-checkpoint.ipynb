# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns
import json
from datetime import datetime as dt

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
#print(url)

# %%
# Create empty lists to append the API data into lists 
city_name = []
temps = []
humid = []
cloudiness = []
wind_speed = []
lats = []
longs = []
country=[]
date=[]

# Start the call counter 
counter = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    
    response = requests.get(f"{url}&q={city}").json()
    try: 
        city_name.append(response["name"])
        temps.append(response["main"]["temp_max"])
        humid.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record {counter} | {city}")
        #print(f"{url}&q={city}")
        
        # Increase counter by one 
        counter = counter + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | san diego
# Processing Record 2 | upernavik
# Processing Record 3 | jagodina
# Processing Record 4 | pevek
# Processing Record 5 | punta arenas
# Processing Record 6 | mataura
# Processing Record 7 | lexington
# Processing Record 8 | taitung
# Processing Record 9 | busselton
# Processing Record 10 | saint-philippe
# Processing Record 11 | vozdvizhenka
# City not found. Skipping...
# Processing Record 12 | teguldet
# Processing Record 13 | albany
# Processing Record 14 | mangai
# City not found. Skipping...
# Processing Record 15 | torbay
# Processing Record 16 | mandalgovi
# Processing Record 17 | baykit
# Processing Record 18 | beroroha
# Processing Record 19 | hilo
# Processing Record 20 | blagodatnoye
# City not found. Skipping...
# Processing Record 21 | lebu
# Processing Record 22 | rikitea
# Processing Record 23 | albina
# Processing Record 24 | alvaraes
# Processing Record 25 | juba
# Processing Record 26 | half moon bay
# Processing Record 27 | port alfred
# Processing Record 28 | bluff
# Processing Record 29 | georgetown
# Processing Record 30 | te anau
# Processing Record 31 | butaritari
# Processing Record 32 | qaanaaq
# Processing Record 33 | porto torres
# Processing Record 34 | bosaso
# Processing Record 35 | puerto ayora
# Processing Record 36 | hobart
# Processing Record 37 | sao borja
# Processing Record 38 | ushuaia
# Processing Record 39 | saint george
# Processing Record 40 | barrow
# Processing Record 41 | kharp
# Processing Record 42 | cape town
# Processing Record 43 | salinas
# Processing Record 44 | lugovoy
# Processing Record 45 | caraballeda
# Processing Record 46 | kavaratti
# City not found. Skipping...
# Processing Record 47 | tres marias
# Processing Record 48 | east london
# Processing Record 49 | cidreira
# Processing Record 50 | bengkulu
# Processing Record 51 | alberton
# Processing Record 52 | portland
# Processing Record 53 | mvuma
# Processing Record 54 | narsaq
# Processing Record 55 | hamilton
# Processing Record 56 | angoche
# Processing Record 57 | shaki
# Processing Record 58 | viedma
# Processing Record 59 | codrington
# Processing Record 60 | avarua
# City not found. Skipping...
# Processing Record 61 | hermanus
# Processing Record 62 | mar del plata
# Processing Record 63 | tasiilaq
# Processing Record 64 | rocha
# Processing Record 65 | kodiak
# Processing Record 66 | sistranda
# Processing Record 67 | esperance
# Processing Record 68 | sorong
# Processing Record 69 | touros
# Processing Record 70 | bintulu
# Processing Record 71 | hithadhoo
# Processing Record 72 | saldanha
# Processing Record 73 | hornepayne
# Processing Record 74 | thompson
# Processing Record 75 | hami
# Processing Record 76 | new norfolk
# Processing Record 77 | pisco
# Processing Record 78 | severo-kurilsk
# Processing Record 79 | castelldefels
# Processing Record 80 | adrar
# Processing Record 81 | thinadhoo
# Processing Record 82 | lasa
# City not found. Skipping...
# Processing Record 83 | jamestown
# Processing Record 84 | tuktoyaktuk
# Processing Record 85 | kailua
# Processing Record 86 | bathsheba
# Processing Record 87 | castrillon
# Processing Record 88 | washougal
# Processing Record 89 | elkton
# Processing Record 90 | constantine
# Processing Record 91 | castro
# Processing Record 92 | hasaki
# Processing Record 93 | meulaboh
# Processing Record 94 | altamira
# Processing Record 95 | norman wells
# Processing Record 96 | saskylakh
# Processing Record 97 | glenluce
# Processing Record 98 | sakakah
# Processing Record 99 | lubbock
# Processing Record 100 | provideniya
# Processing Record 101 | arraial do cabo
# Processing Record 102 | ust-ishim
# City not found. Skipping...
# Processing Record 103 | havoysund
# Processing Record 104 | vilhena
# City not found. Skipping...
# Processing Record 105 | tiksi
# Processing Record 106 | moose factory
# Processing Record 107 | yellowknife
# Processing Record 108 | asbestovskiy
# Processing Record 109 | smithers
# Processing Record 110 | lampang
# Processing Record 111 | bambous virieux
# Processing Record 112 | cabo san lucas
# Processing Record 113 | longyearbyen
# Processing Record 114 | izumo
# Processing Record 115 | atuona
# Processing Record 116 | cap malheureux
# Processing Record 117 | sitka
# Processing Record 118 | port augusta
# Processing Record 119 | alyangula
# Processing Record 120 | kapaa
# Processing Record 121 | asosa
# Processing Record 122 | tezu
# Processing Record 123 | port elizabeth
# Processing Record 124 | nouadhibou
# City not found. Skipping...
# Processing Record 125 | fortuna
# Processing Record 126 | talgar
# Processing Record 127 | warmbad
# Processing Record 128 | luau
# Processing Record 129 | bredasdorp
# Processing Record 130 | aklavik
# Processing Record 131 | paraopeba
# City not found. Skipping...
# Processing Record 132 | hualmay
# Processing Record 133 | nevinnomyssk
# Processing Record 134 | san quintin
# Processing Record 135 | praia da vitoria
# Processing Record 136 | kirakira
# Processing Record 137 | ribeira grande
# Processing Record 138 | sokolo
# City not found. Skipping...
# Processing Record 139 | funes
# Processing Record 140 | khingansk
# Processing Record 141 | carnarvon
# Processing Record 142 | hearst
# Processing Record 143 | misratah
# Processing Record 144 | kununurra
# Processing Record 145 | shingu
# Processing Record 146 | talnakh
# Processing Record 147 | mulanje
# Processing Record 148 | mahebourg
# Processing Record 149 | bailen
# Processing Record 150 | caborca
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 151 | fare
# Processing Record 152 | dali
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 153 | klaksvik
# Processing Record 154 | daru
# Processing Record 155 | kuandian
# Processing Record 156 | caravelas
# Processing Record 157 | geraldton
# Processing Record 158 | katobu
# Processing Record 159 | nome
# Processing Record 160 | nanortalik
# Processing Record 161 | ishigaki
# Processing Record 162 | mhasla
# Processing Record 163 | dhidhdhoo
# Processing Record 164 | kapoeta
# City not found. Skipping...
# Processing Record 165 | kamina
# Processing Record 166 | djambala
# Processing Record 167 | kutum
# Processing Record 168 | yerofey pavlovich
# Processing Record 169 | faya
# Processing Record 170 | talara
# Processing Record 171 | berthierville
# Processing Record 172 | guerrero negro
# Processing Record 173 | beringovskiy
# Processing Record 174 | vaini
# Processing Record 175 | badulla
# Processing Record 176 | wilmington
# Processing Record 177 | airai
# Processing Record 178 | souillac
# Processing Record 179 | dingle
# Processing Record 180 | suzano
# City not found. Skipping...
# Processing Record 181 | hambantota
# Processing Record 182 | muncar
# City not found. Skipping...
# Processing Record 183 | laguna
# Processing Record 184 | burnie
# Processing Record 185 | bethel
# Processing Record 186 | salalah
# Processing Record 187 | marzuq
# Processing Record 188 | bunda
# Processing Record 189 | college
# Processing Record 190 | salgueiro
# City not found. Skipping...
# Processing Record 191 | khatanga
# Processing Record 192 | the valley
# City not found. Skipping...
# Processing Record 193 | fairbanks
# Processing Record 194 | ahipara
# Processing Record 195 | ostrovnoy
# Processing Record 196 | chanute
# Processing Record 197 | ilulissat
# Processing Record 198 | kruisfontein
# Processing Record 199 | gannan
# Processing Record 200 | dikson
# Processing Record 201 | semey
# Processing Record 202 | jiuquan
# Processing Record 203 | bushenyi
# City not found. Skipping...
# Processing Record 204 | ryotsu
# Processing Record 205 | yele
# Processing Record 206 | lakhimpur
# Processing Record 207 | victoria
# Processing Record 208 | olafsvik
# Processing Record 209 | penzance
# Processing Record 210 | iqaluit
# Processing Record 211 | champerico
# Processing Record 212 | makakilo city
# Processing Record 213 | boyolangu
# Processing Record 214 | teknaf
# Processing Record 215 | rodrigues alves
# Processing Record 216 | mayahi
# Processing Record 217 | san patricio
# City not found. Skipping...
# Processing Record 218 | svetlogorsk
# City not found. Skipping...
# Processing Record 219 | punto fijo
# Processing Record 220 | shimoda
# Processing Record 221 | labuhan
# Processing Record 222 | nelson bay
# City not found. Skipping...
# Processing Record 223 | hokitika
# City not found. Skipping...
# Processing Record 224 | deputatskiy
# Processing Record 225 | nikolskoye
# Processing Record 226 | yangliuqing
# Processing Record 227 | wlodawa
# Processing Record 228 | sokolka
# Processing Record 229 | buala
# Processing Record 230 | san carlos
# Processing Record 231 | kurchum
# Processing Record 232 | faanui
# Processing Record 233 | ancud
# Processing Record 234 | towada
# Processing Record 235 | isangel
# Processing Record 236 | mehamn
# Processing Record 237 | yoro
# Processing Record 238 | bud
# Processing Record 239 | amapa
# Processing Record 240 | lakes entrance
# Processing Record 241 | jalu
# Processing Record 242 | ponta do sol
# Processing Record 243 | broken hill
# Processing Record 244 | usolye
# Processing Record 245 | pemangkat
# Processing Record 246 | luderitz
# Processing Record 247 | plettenberg bay
# Processing Record 248 | lorengau
# City not found. Skipping...
# Processing Record 249 | dickinson
# Processing Record 250 | grindavik
# Processing Record 251 | chokurdakh
# Processing Record 252 | riyadh
# Processing Record 253 | san-pedro
# Processing Record 254 | dunedin
# Processing Record 255 | lavrentiya
# Processing Record 256 | north bend
# Processing Record 257 | amos
# Processing Record 258 | saint-augustin
# Processing Record 259 | berlevag
# Processing Record 260 | mittersill
# Processing Record 261 | buritizeiro
# Processing Record 262 | newton
# Processing Record 263 | neiafu
# City not found. Skipping...
# Processing Record 264 | sanchazi
# Processing Record 265 | dryden
# Processing Record 266 | yulara
# Processing Record 267 | mazagao
# Processing Record 268 | kushima
# Processing Record 269 | maltahohe
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 270 | totness
# Processing Record 271 | coihaique
# Processing Record 272 | araouane
# Processing Record 273 | joaima
# Processing Record 274 | bonavista
# Processing Record 275 | sisimiut
# Processing Record 276 | poso
# City not found. Skipping...
# Processing Record 277 | angoram
# Processing Record 278 | xam nua
# Processing Record 279 | barra
# Processing Record 280 | ahmadnagar
# Processing Record 281 | safford
# Processing Record 282 | marseille
# Processing Record 283 | drumnadrochit
# Processing Record 284 | santa cruz do capibaribe
# Processing Record 285 | mujiayingzi
# Processing Record 286 | mackay
# Processing Record 287 | biak
# Processing Record 288 | apache junction
# Processing Record 289 | mezen
# Processing Record 290 | paso blanco
# Processing Record 291 | naze
# Processing Record 292 | namibe
# Processing Record 293 | mpika
# Processing Record 294 | barentu
# Processing Record 295 | yuncheng
# Processing Record 296 | zhigansk
# City not found. Skipping...
# Processing Record 297 | kochinda
# City not found. Skipping...
# Processing Record 298 | tautira
# Processing Record 299 | sinnamary
# Processing Record 300 | yerbogachen
# City not found. Skipping...
# Processing Record 301 | leshukonskoye
# Processing Record 302 | moelv
# Processing Record 303 | vao
# Processing Record 304 | vicuna
# City not found. Skipping...
# Processing Record 305 | quatre cocos
# Processing Record 306 | lakeway
# Processing Record 307 | kavieng
# Processing Record 308 | diffa
# City not found. Skipping...
# Processing Record 309 | cockburn town
# Processing Record 310 | vanimo
# Processing Record 311 | san joaquin
# Processing Record 312 | pinheiro machado
# Processing Record 313 | kosonsoy
# Processing Record 314 | coquimbo
# Processing Record 315 | masvingo
# Processing Record 316 | kizukuri
# Processing Record 317 | talavera
# Processing Record 318 | san jose
# Processing Record 319 | chara
# Processing Record 320 | veraval
# Processing Record 321 | innisfail
# Processing Record 322 | luanda
# Processing Record 323 | sao felix do xingu
# Processing Record 324 | isla vista
# Processing Record 325 | sotnikovo
# Processing Record 326 | esna
# Processing Record 327 | rambha
# Processing Record 328 | ferme-neuve
# Processing Record 329 | sande
# Processing Record 330 | velika kladusa
# Processing Record 331 | tiznit
# Processing Record 332 | chuy
# Processing Record 333 | kudahuvadhoo
# Processing Record 334 | presidencia roque saenz pena
# Processing Record 335 | san cristobal
# Processing Record 336 | sosnovo-ozerskoye
# Processing Record 337 | saharanpur
# Processing Record 338 | belgrade
# Processing Record 339 | nosy varika
# Processing Record 340 | kalemie
# Processing Record 341 | lakatoro
# Processing Record 342 | tuttlingen
# Processing Record 343 | jacareacanga
# Processing Record 344 | vredendal
# Processing Record 345 | san policarpo
# Processing Record 346 | aykhal
# Processing Record 347 | olivet
# Processing Record 348 | poum
# Processing Record 349 | krasnoselkup
# Processing Record 350 | pictou
# Processing Record 351 | caconda
# Processing Record 352 | sarkand
# Processing Record 353 | tocopilla
# Processing Record 354 | yeppoon
# Processing Record 355 | galle
# Processing Record 356 | goderich
# Processing Record 357 | san ramon
# Processing Record 358 | nueve de julio
# Processing Record 359 | rafai
# Processing Record 360 | kalmunai
# Processing Record 361 | abalak
# Processing Record 362 | lata
# Processing Record 363 | takoradi
# Processing Record 364 | manado
# Processing Record 365 | evensk
# City not found. Skipping...
# Processing Record 366 | pangkalanbuun
# Processing Record 367 | naliya
# Processing Record 368 | peniche
# Processing Record 369 | mumford
# City not found. Skipping...
# Processing Record 370 | panaba
# City not found. Skipping...
# Processing Record 371 | marovoay
# Processing Record 372 | bobcaygeon
# Processing Record 373 | lebork
# Processing Record 374 | chumikan
# Processing Record 375 | sao filipe
# Processing Record 376 | navahrudak
# Processing Record 377 | bac lieu
# Processing Record 378 | liverpool
# Processing Record 379 | morehead
# Processing Record 380 | tual
# Processing Record 381 | trelew
# Processing Record 382 | halifax
# Processing Record 383 | karratha
# Processing Record 384 | brezova pod bradlom
# Processing Record 385 | matara
# Processing Record 386 | tinskoy
# Processing Record 387 | bhandara
# Processing Record 388 | nador
# Processing Record 389 | gallup
# Processing Record 390 | turukhansk
# Processing Record 391 | price
# Processing Record 392 | asau
# Processing Record 393 | west wendover
# Processing Record 394 | urucui
# Processing Record 395 | vila velha
# Processing Record 396 | vila franca do campo
# Processing Record 397 | lompoc
# City not found. Skipping...
# Processing Record 398 | erdaojiang
# Processing Record 399 | nicoya
# Processing Record 400 | la ronge
# Processing Record 401 | saint anthony
# Processing Record 402 | romny
# Processing Record 403 | boissevain
# Processing Record 404 | qui nhon
# Processing Record 405 | alice springs
# Processing Record 406 | sept-iles
# Processing Record 407 | taft
# Processing Record 408 | tahe
# Processing Record 409 | tamboril
# Processing Record 410 | labrea
# Processing Record 411 | port lincoln
# Processing Record 412 | ailigandi
# Processing Record 413 | urubicha
# Processing Record 414 | vostok
# Processing Record 415 | tarko-sale
# Processing Record 416 | muli
# Processing Record 417 | doha
# Processing Record 418 | nizhniy lomov
# Processing Record 419 | bandiagara
# Processing Record 420 | palauig
# Processing Record 421 | leningradskiy
# Processing Record 422 | qaqortoq
# Processing Record 423 | pangnirtung
# Processing Record 424 | tabuk
# City not found. Skipping...
# Processing Record 425 | mount isa
# Processing Record 426 | westport
# Processing Record 427 | korla
# Processing Record 428 | sao joao da barra
# Processing Record 429 | ibra
# Processing Record 430 | cherskiy
# Processing Record 431 | arman
# Processing Record 432 | constitucion
# Processing Record 433 | benghazi
# Processing Record 434 | morant bay
# Processing Record 435 | davila
# Processing Record 436 | livingston
# Processing Record 437 | cabedelo
# Processing Record 438 | sibu
# Processing Record 439 | linqiong
# Processing Record 440 | camacha
# Processing Record 441 | alofi
# Processing Record 442 | lagoa
# Processing Record 443 | katsuura
# Processing Record 444 | muros
# Processing Record 445 | margate
# Processing Record 446 | magadan
# Processing Record 447 | ballina
# Processing Record 448 | cape canaveral
# Processing Record 449 | tazovskiy
# Processing Record 450 | grenfell
# Processing Record 451 | corrente
# Processing Record 452 | carlos antonio lopez
# Processing Record 453 | kandrian
# City not found. Skipping...
# Processing Record 454 | anyang
# Processing Record 455 | grand gaube
# Processing Record 456 | menongue
# Processing Record 457 | devarkonda
# Processing Record 458 | nazca
# Processing Record 459 | michigan city
# Processing Record 460 | akniste
# City not found. Skipping...
# Processing Record 461 | chekhov
# Processing Record 462 | opuwo
# Processing Record 463 | los llanos de aridane
# Processing Record 464 | slave lake
# Processing Record 465 | pacific grove
# Processing Record 466 | tabira
# Processing Record 467 | mount gambier
# Processing Record 468 | todos santos
# Processing Record 469 | tacuarembo
# Processing Record 470 | maubeuge
# Processing Record 471 | pizarro
# Processing Record 472 | tuatapere
# Processing Record 473 | nuuk
# Processing Record 474 | palenque
# Processing Record 475 | kaitangata
# Processing Record 476 | iquique
# Processing Record 477 | ouegoa
# Processing Record 478 | mirador
# Processing Record 479 | sangar
# Processing Record 480 | parainen
# Processing Record 481 | richards bay
# Processing Record 482 | grants
# Processing Record 483 | huicungo
# Processing Record 484 | kaabong
# Processing Record 485 | houma
# Processing Record 486 | duverge
# Processing Record 487 | varhaug
# Processing Record 488 | hiranagar
# Processing Record 489 | tsabong
# Processing Record 490 | mogadishu
# Processing Record 491 | batemans bay
# Processing Record 492 | newberry
# Processing Record 493 | honningsvag
# Processing Record 494 | yumen
# Processing Record 495 | mahuva
# Processing Record 496 | bella vista
# Processing Record 497 | tubuala
# Processing Record 498 | porto murtinho
# Processing Record 499 | isiro
# Processing Record 500 | sioux lookout
# Processing Record 501 | bima
# Processing Record 502 | rypefjord
# Processing Record 503 | linden
# Processing Record 504 | xinzhou
# Processing Record 505 | makat
# Processing Record 506 | bijapur
# Processing Record 507 | erzin
# Processing Record 508 | ulagan
# Processing Record 509 | haines junction
# Processing Record 510 | waitati
# Processing Record 511 | scotts valley
# Processing Record 512 | leh
# Processing Record 513 | takab
# Processing Record 514 | marienburg
# Processing Record 515 | nishihara
# Processing Record 516 | afua
# Processing Record 517 | severnoye
# Processing Record 518 | dwarka
# City not found. Skipping...
# Processing Record 519 | villa carlos paz
# Processing Record 520 | gao
# Processing Record 521 | saint-joseph
# Processing Record 522 | belyy yar
# Processing Record 523 | ushtobe
# Processing Record 524 | banjar
# Processing Record 525 | kloulklubed
# Processing Record 526 | dicabisagan
# Processing Record 527 | taoudenni
# Processing Record 528 | semnan
# Processing Record 529 | lake station
# Processing Record 530 | kahului
# Processing Record 531 | salinopolis
# City not found. Skipping...
# Processing Record 532 | anisoc
# Processing Record 533 | mamallapuram
# Processing Record 534 | sabang
# Processing Record 535 | cayenne
# Processing Record 536 | savannah bight
# Processing Record 537 | urengoy
# Processing Record 538 | vanavara
# Processing Record 539 | antalaha
# Processing Record 540 | motygino
# Processing Record 541 | puerto quijarro
# Processing Record 542 | touho
# Processing Record 543 | raudeberg
# Processing Record 544 | hyeres
# Processing Record 545 | aksu
# Processing Record 546 | asfi
# Processing Record 547 | kyzyl-suu

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dataframe
city_weather_df = pd.DataFrame({
    "City" : city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humid,
    "Latitude": lats,
    "Longitude" :longs,
    "Max Temp": temps,
    "Wind Speed": wind_speed,
})
city_weather_df.count()
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Latitude      547
# Longitude     547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# save it to CSV file
city_weather_df.to_csv("data/CityData.csv")

# Display data frame head 
city_weather_df.head(10)
# Out:
#              City  Cloudiness Country        Date  Humidity  Latitude  \
# 0       San Diego          75      US  1604603448        31     32.72
# 1       Upernavik          40      GL  1604603267        91     72.79
# 2        Jagodina          75      RS  1604603489       100     43.98
# 3           Pevek         100      RU  1604603204        95     69.70
# 4    Punta Arenas          75      CL  1604603274        46    -53.15
# 5         Mataura         100      NZ  1604603269        96    -46.19
# 6       Lexington           1      US  1604603434        48     37.99
# 7    Taitung City         100      TW  1604603490        68     22.76
# 8       Busselton           0      AU  1604603262        81    -33.65
# 9  Saint-Philippe          39      RE  1604603281        64    -21.36
#
#    Longitude  Max Temp  Wind Speed
# 0    -117.16     89.01        4.70
# 1     -56.15      7.50        6.55
# 2      21.26     53.60        5.82
# 3     170.31     29.01       22.77
# 4     -70.92     51.80       17.22
# 5     168.86     46.00        1.01
# 6     -84.48     66.00       10.29
# 7     121.14     78.17       14.94
# 8     115.33     55.99        7.00
# 9      55.77     71.60        5.82

# %%
# Calculate current date from datetime library
current_date = dt.now().strftime("(%m/%d/%Y)")
print(current_date)
# Out:
# (11/05/2020)

# %% [markdown]
# ### Plotting the Data
# * Used proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Saved the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#scatter plot Latitude vs Max Temp
plt.scatter(city_weather_df["Latitude"], city_weather_df["Max Temp"], marker="o",s=20,facecolors="green",edgecolor = "black", alpha=0.75)

# Incorporate the graph properties
plt.title("City Latitude vs. Max Temperature" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Max Temperature(F)",fontsize = 13)
sns.set_style('darkgrid')
plt.ylim(min(city_weather["Max Temp"])-20, max(city_weather["Max Temp"])+20)
plt.grid(True)

#save the figure
plt.savefig("Images/Temperature_in_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showcase the relationship between Latitude at x-axis vs Max Temperature (F) at the y-axis. This result indicates that there is a higher temrature for the cities that found near to the equater (Latitude 0),however when you go farther from the equator towrads to the north and south the temprature will decrease.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#scatter plot of Humidity vs latitude
plt.scatter(city_weather_df["Latitude"], city_weather_df["Humidity"], marker="o",s=20, facecolors="green",edgecolor = "black", alpha=0.75)

# Incorporate the graph properties
plt.title("City Latitude vs Humidity" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Humidity (%)",fontsize = 13)
plt.xlim(-80, 90)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Humidity_in_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot displayed the relationship between Humidity (%) vs. Latitude. From the result we can infer that humidity is fairly distributed troughout the plot, so we can say that high humidity occer for both cities found farther or near to the equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#scatter plot of Latitude Vs Cloudiness
plt.scatter(city_weather_df["Latitude"], city_weather_df["Cloudiness"], marker="o",s=20, facecolors="green", edgecolor = "black", alpha=0.75)

# Incorporate the graph properties
plt.title("City Latitude vs Cloudiness" + " " + current_date ,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Cloudiness (%)",fontsize = 13)
plt.ylim(min(city_weather["Cloudiness"])-10, max(city_weather["Cloudiness"])+10)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Cloudiness_In_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showed the relationship between the cities cloudness, and latitude. From this result we can tell that the data is evenly distributed, and there is no difference in Cloudiness when the cities farther or nearer to the equater(Latitude 0).

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# scatter plot of latitude vs wind speed
plt.scatter(city_weather_df["Latitude"], city_weather_df["Wind Speed"],marker="o",s=20, facecolors="green", edgecolor = "black", alpha=0.75)

# Incorporate the graph properties
plt.title("City Latitude vs Wind Speed" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Wind Speed (mph)",fontsize = 13)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Wind_Speed_In_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showed the relationship between wind speed (mph), and latitude. The plot displayed the lower wind speed when the cities closer to the equater (latitude 0) and somehow the wind speed increases for the cities farther from the equator (Latitude 60).
