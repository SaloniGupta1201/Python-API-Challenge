# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

# %%
#!pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns
import json
from datetime import datetime as dt
import scipy.stats as st
from scipy.stats import linregress

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 595

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
#print(url)

# %%
# Create empty lists to append the API data into lists 
city_name = []
temps = []
humid = []
cloudiness = []
wind_speed = []
lats = []
longs = []
country=[]
date=[]

# Start the call counter 
counter = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    
    response = requests.get(f"{url}&q={city}").json()
    try: 
        city_name.append(response["name"])
        temps.append(response["main"]["temp_max"])
        humid.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        print(f"Processing Record {counter} | {city}")
        #print(f"{url}&q={city}")
        
        # Increase counter by one 
        counter = counter + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | avarua
# Processing Record 2 | montelibano
# Processing Record 3 | vaini
# Processing Record 4 | vanimo
# Processing Record 5 | dali
# Processing Record 6 | haines junction
# Processing Record 7 | bluff
# Processing Record 8 | punta arenas
# Processing Record 9 | east london
# Processing Record 10 | rikitea
# Processing Record 11 | miles city
# Processing Record 12 | novobiryusinskiy
# Processing Record 13 | fortuna
# Processing Record 14 | nome
# Processing Record 15 | council bluffs
# Processing Record 16 | muzhi
# Processing Record 17 | najran
# Processing Record 18 | solnechnyy
# Processing Record 19 | buckeye
# Processing Record 20 | lubuagan
# Processing Record 21 | coihaique
# City not found. Skipping...
# Processing Record 22 | margate
# Processing Record 23 | esna
# Processing Record 24 | ushuaia
# City not found. Skipping...
# Processing Record 25 | hambantota
# Processing Record 26 | qaanaaq
# Processing Record 27 | bethel
# Processing Record 28 | faanui
# Processing Record 29 | thompson
# Processing Record 30 | busselton
# Processing Record 31 | port alfred
# Processing Record 32 | coquimbo
# Processing Record 33 | kahului
# Processing Record 34 | helena
# Processing Record 35 | hilo
# Processing Record 36 | yellowknife
# Processing Record 37 | vardo
# Processing Record 38 | saint george
# Processing Record 39 | ribeira grande
# Processing Record 40 | north bend
# Processing Record 41 | lata
# Processing Record 42 | tual
# City not found. Skipping...
# Processing Record 43 | katsuura
# Processing Record 44 | axim
# Processing Record 45 | bredasdorp
# Processing Record 46 | hithadhoo
# City not found. Skipping...
# Processing Record 47 | constitucion
# Processing Record 48 | meulaboh
# Processing Record 49 | nabire
# Processing Record 50 | asfi
# Processing Record 51 | nemuro
# Processing Record 52 | dukat
# Processing Record 53 | narsaq
# Processing Record 54 | saiha
# Processing Record 55 | zaysan
# Processing Record 56 | kataysk
# Processing Record 57 | shahrud
# Processing Record 58 | arlit
# Processing Record 59 | pisco
# Processing Record 60 | barrow
# Processing Record 61 | jamestown
# Processing Record 62 | albany
# Processing Record 63 | atuona
# City not found. Skipping...
# Processing Record 64 | barra do garcas
# Processing Record 65 | padang
# Processing Record 66 | staryy nadym
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 67 | port elizabeth
# Processing Record 68 | leningradskiy
# Processing Record 69 | nikolskoye
# Processing Record 70 | tasiilaq
# Processing Record 71 | kysyl-syr
# Processing Record 72 | mataura
# Processing Record 73 | kapaa
# Processing Record 74 | hobart
# Processing Record 75 | tuktoyaktuk
# Processing Record 76 | bardiyah
# Processing Record 77 | saravena
# Processing Record 78 | sitka
# Processing Record 79 | nanortalik
# Processing Record 80 | sambava
# City not found. Skipping...
# Processing Record 81 | samarai
# Processing Record 82 | lulea
# Processing Record 83 | eyl
# Processing Record 84 | hermanus
# Processing Record 85 | georgetown
# Processing Record 86 | kavieng
# City not found. Skipping...
# Processing Record 87 | la reforma
# Processing Record 88 | victoria
# Processing Record 89 | virden
# Processing Record 90 | pocao de pedras
# Processing Record 91 | monroe
# Processing Record 92 | kurilsk
# Processing Record 93 | turukhansk
# Processing Record 94 | olafsvik
# Processing Record 95 | kruisfontein
# Processing Record 96 | airai
# Processing Record 97 | esperance
# Processing Record 98 | khiv
# Processing Record 99 | sinnamary
# Processing Record 100 | deputatskiy
# Processing Record 101 | bridlington
# Processing Record 102 | dikson
# Processing Record 103 | stettler
# Processing Record 104 | olinda
# Processing Record 105 | geraldton
# Processing Record 106 | tucuman
# Processing Record 107 | mahebourg
# Processing Record 108 | norman wells
# City not found. Skipping...
# Processing Record 109 | sarahan
# Processing Record 110 | puerto ayora
# Processing Record 111 | rawah
# Processing Record 112 | gamba
# Processing Record 113 | naze
# Processing Record 114 | bambous virieux
# Processing Record 115 | rustam
# Processing Record 116 | poso
# Processing Record 117 | hare bay
# Processing Record 118 | necochea
# Processing Record 119 | mednogorskiy
# Processing Record 120 | saint-philippe
# Processing Record 121 | porbandar
# Processing Record 122 | hell
# Processing Record 123 | wattegama
# Processing Record 124 | kasempa
# Processing Record 125 | winnemucca
# Processing Record 126 | arraial do cabo
# Processing Record 127 | lebu
# Processing Record 128 | mahajanga
# Processing Record 129 | lavrentiya
# Processing Record 130 | natal
# Processing Record 131 | richards bay
# Processing Record 132 | lagoa
# Processing Record 133 | cape town
# Processing Record 134 | butaritari
# Processing Record 135 | vila velha
# Processing Record 136 | soe
# Processing Record 137 | new norfolk
# Processing Record 138 | boca do acre
# Processing Record 139 | castro
# City not found. Skipping...
# Processing Record 140 | guerrero negro
# City not found. Skipping...
# Processing Record 141 | newport
# Processing Record 142 | krasnoselkup
# City not found. Skipping...
# Processing Record 143 | flin flon
# Processing Record 144 | borogontsy
# Processing Record 145 | san nicolas
# Processing Record 146 | tautira
# Processing Record 147 | christchurch
# City not found. Skipping...
# Processing Record 148 | bambanglipuro
# City not found. Skipping...
# Processing Record 149 | pevek
# Processing Record 150 | basco
# Processing Record 151 | bayamo
# Processing Record 152 | kumluca
# Processing Record 153 | kodiak
# Processing Record 154 | langsa
# Processing Record 155 | mar del plata
# Processing Record 156 | talnakh
# Processing Record 157 | saint-pierre
# Processing Record 158 | sistranda
# Processing Record 159 | akyab
# Processing Record 160 | mathathane
# Processing Record 161 | hailey
# Processing Record 162 | veraval
# Processing Record 163 | kenai
# Processing Record 164 | wasilla
# Processing Record 165 | vostok
# Processing Record 166 | san patricio
# Processing Record 167 | bilibino
# Processing Record 168 | avigliano
# Processing Record 169 | bubaque
# Processing Record 170 | pokhara
# Processing Record 171 | lancaster
# Processing Record 172 | bengkulu
# Processing Record 173 | provideniya
# Processing Record 174 | tomatlan
# Processing Record 175 | yueyang
# Processing Record 176 | baringo
# Processing Record 177 | doka
# Processing Record 178 | yarada
# Processing Record 179 | inirida
# Processing Record 180 | fort saint james
# Processing Record 181 | ponta do sol
# Processing Record 182 | qurayyat
# Processing Record 183 | okitipupa
# Processing Record 184 | cherskiy
# Processing Record 185 | caravelas
# Processing Record 186 | torbay
# Processing Record 187 | belyy yar
# Processing Record 188 | gigmoto
# Processing Record 189 | amga
# Processing Record 190 | polunochnoye
# Processing Record 191 | prescott valley
# City not found. Skipping...
# Processing Record 192 | hofn
# Processing Record 193 | maragogi
# Processing Record 194 | luderitz
# Processing Record 195 | klaksvik
# City not found. Skipping...
# Processing Record 196 | lappeenranta
# Processing Record 197 | beringovskiy
# Processing Record 198 | te anau
# Processing Record 199 | andenes
# Processing Record 200 | dubbo
# City not found. Skipping...
# Processing Record 201 | byron bay
# City not found. Skipping...
# Processing Record 202 | ilulissat
# Processing Record 203 | makkaveyevo
# Processing Record 204 | faya
# Processing Record 205 | san pedro
# City not found. Skipping...
# Processing Record 206 | ouegoa
# Processing Record 207 | cayambe
# City not found. Skipping...
# Processing Record 208 | storforshei
# Processing Record 209 | belmonte
# Processing Record 210 | tiksi
# Processing Record 211 | yulara
# Processing Record 212 | vondrozo
# Processing Record 213 | thinadhoo
# Processing Record 214 | baiao
# Processing Record 215 | coihueco
# Processing Record 216 | iqaluit
# Processing Record 217 | tereze
# Processing Record 218 | mende
# Processing Record 219 | ancud
# Processing Record 220 | cidreira
# Processing Record 221 | pacifica
# Processing Record 222 | lompoc
# Processing Record 223 | batagay-alyta
# Processing Record 224 | mehamn
# Processing Record 225 | karratha
# City not found. Skipping...
# Processing Record 226 | oneonta
# Processing Record 227 | nieuw amsterdam
# Processing Record 228 | kyrylivka
# Processing Record 229 | cumberland
# Processing Record 230 | mizdah
# Processing Record 231 | sumbawanga
# Processing Record 232 | victor harbor
# City not found. Skipping...
# Processing Record 233 | changchun
# Processing Record 234 | roma
# Processing Record 235 | indramayu
# Processing Record 236 | porterville
# Processing Record 237 | ler
# Processing Record 238 | chokurdakh
# Processing Record 239 | annau
# City not found. Skipping...
# Processing Record 240 | usinsk
# Processing Record 241 | rafai
# Processing Record 242 | port lincoln
# Processing Record 243 | khatanga
# City not found. Skipping...
# Processing Record 244 | george
# Processing Record 245 | saldanha
# City not found. Skipping...
# Processing Record 246 | baruun-urt
# Processing Record 247 | honiara
# Processing Record 248 | paamiut
# City not found. Skipping...
# Processing Record 249 | san andres
# Processing Record 250 | aykhal
# City not found. Skipping...
# Processing Record 251 | kisanga
# Processing Record 252 | inhambane
# Processing Record 253 | komsomolskiy
# Processing Record 254 | ust-nera
# Processing Record 255 | yangambi
# City not found. Skipping...
# Processing Record 256 | avera
# Processing Record 257 | naryan-mar
# Processing Record 258 | morro bay
# Processing Record 259 | high level
# Processing Record 260 | kindu
# Processing Record 261 | yenagoa
# Processing Record 262 | alofi
# Processing Record 263 | husavik
# City not found. Skipping...
# Processing Record 264 | carnarvon
# Processing Record 265 | cheremukhovo
# Processing Record 266 | bhilai
# Processing Record 267 | ndele
# Processing Record 268 | neuquen
# Processing Record 269 | obama
# Processing Record 270 | berlevag
# Processing Record 271 | manado
# Processing Record 272 | wajid
# Processing Record 273 | saint anthony
# Processing Record 274 | liusha
# Processing Record 275 | vao
# Processing Record 276 | griffith
# Processing Record 277 | muros
# Processing Record 278 | calama
# Processing Record 279 | sao joao da barra
# Processing Record 280 | iquique
# Processing Record 281 | sioux lookout
# Processing Record 282 | sao filipe
# Processing Record 283 | dinguiraye
# Processing Record 284 | whitehorse
# Processing Record 285 | ampanihy
# Processing Record 286 | maningrida
# Processing Record 287 | ha tinh
# Processing Record 288 | salalah
# City not found. Skipping...
# Processing Record 289 | vieste
# Processing Record 290 | port hedland
# Processing Record 291 | coahuayana
# City not found. Skipping...
# Processing Record 292 | saint-francois
# Processing Record 293 | grand gaube
# Processing Record 294 | gagarin
# Processing Record 295 | korla
# Processing Record 296 | severo-kurilsk
# Processing Record 297 | hamilton
# Processing Record 298 | jacareacanga
# City not found. Skipping...
# Processing Record 299 | tuatapere
# Processing Record 300 | old saybrook
# Processing Record 301 | sibolga
# Processing Record 302 | salinopolis
# Processing Record 303 | da nang
# Processing Record 304 | koungou
# City not found. Skipping...
# Processing Record 305 | aksarka
# Processing Record 306 | khawhai
# Processing Record 307 | saskylakh
# City not found. Skipping...
# Processing Record 308 | price
# Processing Record 309 | roswell
# Processing Record 310 | shemursha
# Processing Record 311 | porto santo
# Processing Record 312 | san alberto
# Processing Record 313 | susanino
# Processing Record 314 | ketchikan
# Processing Record 315 | jiangyou
# City not found. Skipping...
# Processing Record 316 | markova
# Processing Record 317 | szazhalombatta
# Processing Record 318 | sabang
# Processing Record 319 | manta
# Processing Record 320 | isangel
# City not found. Skipping...
# Processing Record 321 | laramie
# Processing Record 322 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 323 | zharkovskiy
# Processing Record 324 | upernavik
# Processing Record 325 | havre-saint-pierre
# Processing Record 326 | pacific grove
# Processing Record 327 | denpasar
# Processing Record 328 | imeni poliny osipenko
# Processing Record 329 | cloquet
# Processing Record 330 | busayra
# Processing Record 331 | strezhevoy
# Processing Record 332 | bowen
# City not found. Skipping...
# Processing Record 333 | cabo san lucas
# Processing Record 334 | killybegs
# Processing Record 335 | morales
# Processing Record 336 | teguldet
# Processing Record 337 | mount isa
# Processing Record 338 | nador
# City not found. Skipping...
# Processing Record 339 | quesnel
# Processing Record 340 | edeia
# Processing Record 341 | inongo
# Processing Record 342 | khoy
# Processing Record 343 | cap malheureux
# Processing Record 344 | nara
# Processing Record 345 | fomboni
# Processing Record 346 | grenaa
# City not found. Skipping...
# Processing Record 347 | chuy
# Processing Record 348 | pontes e lacerda
# Processing Record 349 | sayyan
# City not found. Skipping...
# Processing Record 350 | kashi
# Processing Record 351 | mwinilunga
# Processing Record 352 | shu
# Processing Record 353 | abu dhabi
# Processing Record 354 | ostrovnoy
# Processing Record 355 | la ronge
# Processing Record 356 | erenhot
# Processing Record 357 | gboko
# Processing Record 358 | maine-soroa
# Processing Record 359 | codrington
# Processing Record 360 | nisia floresta
# Processing Record 361 | conceicao do mato dentro
# Processing Record 362 | lakes entrance
# Processing Record 363 | ugoofaaru
# Processing Record 364 | payo
# Processing Record 365 | shreveport
# Processing Record 366 | pucallpa
# City not found. Skipping...
# Processing Record 367 | canavieiras
# Processing Record 368 | altay
# Processing Record 369 | lerwick
# Processing Record 370 | velikodvorskiy
# Processing Record 371 | brastavatu
# Processing Record 372 | cabimas
# Processing Record 373 | garowe
# Processing Record 374 | hasaki
# Processing Record 375 | marawi
# Processing Record 376 | sur
# City not found. Skipping...
# Processing Record 377 | adrar
# Processing Record 378 | makakilo city
# Processing Record 379 | kieta
# Processing Record 380 | mossendjo
# Processing Record 381 | caluquembe
# Processing Record 382 | kelowna
# City not found. Skipping...
# Processing Record 383 | diamantina
# Processing Record 384 | port macquarie
# Processing Record 385 | sawai madhopur
# Processing Record 386 | birnin kebbi
# Processing Record 387 | puerto escondido
# Processing Record 388 | pyaozerskiy
# Processing Record 389 | dodoma
# Processing Record 390 | goderich
# Processing Record 391 | anadyr
# Processing Record 392 | mokhsogollokh
# Processing Record 393 | pareora
# Processing Record 394 | omsukchan
# Processing Record 395 | karacakoy
# Processing Record 396 | paka
# Processing Record 397 | hauzenberg
# Processing Record 398 | prescott
# Processing Record 399 | mangrol
# Processing Record 400 | pemangkat
# Processing Record 401 | sao jose da coroa grande
# Processing Record 402 | ballina
# Processing Record 403 | shingu
# Processing Record 404 | verkhnetulomskiy
# Processing Record 405 | mitsamiouli
# Processing Record 406 | henties bay
# Processing Record 407 | shagonar
# Processing Record 408 | ahipara
# Processing Record 409 | lithakia
# City not found. Skipping...
# Processing Record 410 | russell
# Processing Record 411 | port blair
# City not found. Skipping...
# Processing Record 412 | kirakira
# Processing Record 413 | madona
# Processing Record 414 | hirtshals
# Processing Record 415 | fairbanks
# Processing Record 416 | ternate
# Processing Record 417 | raga
# Processing Record 418 | araouane
# Processing Record 419 | nampula
# Processing Record 420 | portland
# Processing Record 421 | jian
# Processing Record 422 | itarema
# Processing Record 423 | longyearbyen
# Processing Record 424 | zamora
# Processing Record 425 | touros
# Processing Record 426 | mayumba
# Processing Record 427 | makhachkala
# Processing Record 428 | pierre
# Processing Record 429 | sancti spiritus
# Processing Record 430 | olutanga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 431 | ginda
# Processing Record 432 | millau
# Processing Record 433 | eureka
# Processing Record 434 | cuenca
# Processing Record 435 | verkhnyaya inta
# Processing Record 436 | souillac
# Processing Record 437 | sisimiut
# Processing Record 438 | taklisah
# Processing Record 439 | hami
# Processing Record 440 | priargunsk
# Processing Record 441 | soderhamn
# Processing Record 442 | antofagasta
# Processing Record 443 | boffa
# Processing Record 444 | bedesa
# Processing Record 445 | abalak
# Processing Record 446 | villa carlos paz
# Processing Record 447 | katesh
# Processing Record 448 | kanker
# Processing Record 449 | gari
# Processing Record 450 | wanning
# Processing Record 451 | mahanje
# Processing Record 452 | benghazi
# Processing Record 453 | huarmey
# Processing Record 454 | cockburn town
# Processing Record 455 | ostersund
# Processing Record 456 | novikovo
# Processing Record 457 | iskateley
# Processing Record 458 | tura
# Processing Record 459 | luanda
# Processing Record 460 | forrest city
# Processing Record 461 | teyateyaneng
# Processing Record 462 | namibe
# Processing Record 463 | lamesa
# Processing Record 464 | pochutla
# Processing Record 465 | bud
# Processing Record 466 | sechura
# Processing Record 467 | nahavand
# Processing Record 468 | diffa
# Processing Record 469 | swan hill
# Processing Record 470 | balabac
# Processing Record 471 | sundumbili
# Processing Record 472 | alto araguaia
# City not found. Skipping...
# Processing Record 473 | berdigestyakh
# Processing Record 474 | jiayuguan
# Processing Record 475 | oeiras
# Processing Record 476 | washington
# Processing Record 477 | bjornevatn
# Processing Record 478 | lakatoro
# Processing Record 479 | sampit
# Processing Record 480 | seoul
# Processing Record 481 | algarrobo
# Processing Record 482 | concordia
# Processing Record 483 | vaitape
# Processing Record 484 | arrifes
# Processing Record 485 | mount gambier
# Processing Record 486 | talaya
# Processing Record 487 | torbat-e jam
# Processing Record 488 | caborca
# Processing Record 489 | sadao
# Processing Record 490 | kaitangata
# City not found. Skipping...
# Processing Record 491 | pachino
# Processing Record 492 | olot
# Processing Record 493 | novyy svit
# Processing Record 494 | hot springs
# Processing Record 495 | dhar
# City not found. Skipping...
# Processing Record 496 | buala
# Processing Record 497 | saint-georges
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 498 | fort nelson
# Processing Record 499 | harper
# Processing Record 500 | raudeberg
# Processing Record 501 | santa marta
# Processing Record 502 | palafrugell
# Processing Record 503 | kalmunai
# Processing Record 504 | san marcos
# Processing Record 505 | nishihara
# Processing Record 506 | wilmington
# Processing Record 507 | berck
# Processing Record 508 | manubul
# Processing Record 509 | ladovskaya balka
# Processing Record 510 | ankang
# Processing Record 511 | manzanillo
# Processing Record 512 | fukuma
# Processing Record 513 | horqueta
# Processing Record 514 | dawson
# Processing Record 515 | gat
# Processing Record 516 | udachnyy
# Processing Record 517 | xichang
# Processing Record 518 | nouadhibou
# Processing Record 519 | namatanai
# City not found. Skipping...
# Processing Record 520 | san cristobal
# Processing Record 521 | guiratinga
# Processing Record 522 | taunggyi
# Processing Record 523 | port-gentil
# Processing Record 524 | amapa
# Processing Record 525 | palmer
# Processing Record 526 | bolobo
# City not found. Skipping...
# Processing Record 527 | bela vista do paraiso
# Processing Record 528 | longonjo
# Processing Record 529 | minas
# Processing Record 530 | baykit
# City not found. Skipping...
# Processing Record 531 | half moon bay
# Processing Record 532 | kavaratti
# Processing Record 533 | bonavista
# Processing Record 534 | simpang
# Processing Record 535 | kabwe
# Processing Record 536 | den helder
# Processing Record 537 | opuwo
# Processing Record 538 | camana

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create dataframe
city_weather_df = pd.DataFrame({
    "City" : city_name,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humid,
    "Latitude": lats,
    "Longitude" :longs,
    "Max Temp": temps,
    "Wind Speed": wind_speed,
})
city_weather_df.count()
# Out:
# City          538
# Cloudiness    538
# Country       538
# Date          538
# Humidity      538
# Latitude      538
# Longitude     538
# Max Temp      538
# Wind Speed    538
# dtype: int64

# %%
# save it to CSV file
city_weather_df.to_csv("data/CityData.csv")

# Display data frame head 
city_weather_df.head(10)
# Out:
#               City  Cloudiness Country        Date  Humidity  Latitude  \
# 0           Avarua           0      CK  1605032131        78    -21.21
# 1      Montelíbano          95      CO  1605032132        67      7.98
# 2            Vaini          20      TO  1605032134        88    -21.20
# 3           Vanimo          88      PG  1605032135        78     -2.67
# 4             Dali          50      CN  1605032137        72     25.70
# 5  Haines Junction          37      CA  1605032138        84     60.75
# 6            Bluff          16      NZ  1605032141        96    -46.60
# 7     Punta Arenas          40      CL  1605032049        55    -53.15
# 8      East London          75      ZA  1605032143        93    -33.02
# 9          Rikitea           0      PF  1605032145        79    -23.12
#
#    Longitude  Max Temp  Wind Speed
# 0    -159.78     78.80        8.05
# 1     -75.42     86.36        5.77
# 2    -175.20     73.40        6.93
# 3     141.30     79.54        1.63
# 4     100.18     51.24        2.13
# 5    -137.51     -0.40        1.12
# 6     168.33     46.00        5.68
# 7     -70.92     62.60       12.75
# 8      27.91     60.80        4.70
# 9    -134.97     73.87       17.78

# %%
# Calculate current date from datetime library
current_date = dt.now().strftime("(%m/%d/%Y)")
print(current_date)
# Out:
# (11/10/2020)

# %% [markdown]
# ### Plotting the Data
# * Used proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Saved the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Create a scatter plot Latitude vs Max Temp
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Max Temp"], marker="o",s=30,facecolors="green",edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs. Max Temperature" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Max Temperature(F)",fontsize = 13)
sns.set_style('darkgrid')
plt.ylim(min(city_weather_df["Max Temp"])-20, max(city_weather_df["Max Temp"])+20)
plt.grid(True)

#save the figure
plt.savefig("Images/Temperature_in_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showcase the relationship between Latitude at x-axis vs Max Temperature (F) at the y-axis. This result indicates that there is a higher temrature for the cities that found near to the equater (Latitude 0),however when you go farther from the equator towrads to the north and south the temprature will decrease.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot of Humidity vs latitude
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Humidity"], marker="o",s=30, facecolors="green",edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs Humidity" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Humidity (%)",fontsize = 13)
plt.xlim(-80, 90)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Humidity_in_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot displayed the relationship between Humidity (%) vs. Latitude. From the result we can infer that humidity is fairly distributed troughout the plot, so we can say that high humidity occer for both cities found farther or near to the equator.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Create a scatter plot of Latitude Vs Cloudiness
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Cloudiness"], marker="o", facecolors="green", edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs Cloudiness" + " " + current_date ,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Cloudiness (%)",fontsize = 13)
plt.ylim(min(city_weather_df["Cloudiness"])-10, max(city_weather_df["Cloudiness"])+10)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Cloudiness_In_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showed the relationship between the cities cloudness, and latitude. From this result we can tell that the data is evenly distributed, and there is no difference in Cloudiness when the cities farther or nearer to the equater(Latitude 0).

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Create a scatter plot of latitude vs wind speed
fig1, ax1 = plt.subplots(figsize=(10,6))
plt.scatter(city_weather_df["Latitude"], city_weather_df["Wind Speed"],marker="o",s=30, facecolors="green", edgecolor = "black", alpha=1)

# Incorporate the graph properties
plt.title("City Latitude vs Wind Speed" + " " + current_date,fontsize = 15)
plt.xlabel("Latitude",fontsize = 13)
plt.ylabel("Wind Speed (mph)",fontsize = 13)
plt.grid(True)
sns.set_style('darkgrid')

#save the figure
plt.savefig("Images/Wind_Speed_In_World_Cities.png")

#show plot
plt.show()

# %% [markdown]
# ##### The above scatter plot showed the relationship between wind speed (mph), and latitude. The plot displayed the lower wind speed when the cities closer to the equater (latitude 0) and somehow the wind speed increases for the cities farther from the equator (Latitude 60).

# %%
#Create a function to create Linear Regression plots
def createLinearRegressionPlot(x_values, y_values, x_label, y_label, hemisphere, line_placement, ylim=None):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
    regress_values = x_values * slope + intercept

# Create line equation string
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot linear regression on top of scatter plot
    fig1, ax1 = plt.subplots(figsize=(10, 6))
    plt.scatter(x_values,y_values,color = 'purple',edgecolor = "black",alpha = 0.80, linewidths = 1)

# Add labels and title to plot
    plt.title(f"{hemisphere} Hemisphere - {x_label} vs {y_label} Linear Regression {current_date}",fontsize = 16)
    plt.xlabel(x_label,fontsize = 14)
    plt.ylabel(y_label,fontsize = 14)
    plt.grid(True)

# Annotate linear regression
    plt.annotate(line_eq,(10, 50),fontsize=20,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction', horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-20, 40),fontsize=20,xycoords='data',xytext=(0.4, 0.3), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(10, 25),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
    plt.annotate(line_eq,xy=(-40, 10),fontsize=22,xycoords='data',xytext=(0.4, 0.4), textcoords='axes fraction',horizontalalignment='right', verticalalignment='top',color="red")
# Print correlation and r square value
    print(f"The correlation between both factors is : {round(st.pearsonr(x_values, y_values)[0],2)}")
    print(f"The r-squared is: {round(rvalue**2,2)}")

    return plt.plot(x_values,regress_values,"r-")

# %%
# Create Northern and Southern Hemisphere DataFrames

northern_hemisphere = city_weather_df.loc[city_weather_df["Latitude"] >= 0]
southern_hemisphere = city_weather_df.loc[city_weather_df["Latitude"] < 0]

# %% [markdown]
# #### Northern Hemisphere - Max Temp(F) vs. Latitude Linear Regression

# %%
#linear regression model for latitude vs max temp (northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Max Temp']

createLinearRegressionPlot(x_values, y_values, "Latitude", "Max Temp(F)","Northern",(0, 0))

plt.savefig("Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png", bbox_inches = "tight")
plt.show()
# Out:
# The correlation between both factors is : -0.85
# The r-squared is: 0.72

# %% [markdown]
# #### The above scattered graph is a linear regression model between Maximum Temperature and Latitude for Northern Hemisphere cities. The result from the data showed that there is a strong negative correlation between Maximum Temperature and Latitude which means when we go farther away from the equater(latitude 0) the maximum Temperature (F) will decrease.

# %% [markdown]
# #### Southern Hemisphere - Max Temp(F) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs max temp (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Max Temp']

createLinearRegressionPlot(x_values, y_values, "Latitude", "Max Temp(F)", "Southern",(-30, 60))
# Create line equation string
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
#plt.annotate(line_eq,(-20,50),fontsize=15,color="red")
plt.savefig("Images/Southern_Hemisphere_Max_Temp_vs._Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.66
# The r-squared is: 0.44

# %% [markdown]
# #### The above scattered graph is a linear regression model between Maximum Temperature and Latitude for Southern Hemisphere cities. The result from the data showed that there is a moderate positive correlation between latitude and max temperature for southern hemisphere.

# %% [markdown]
# #### Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humidity (northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Humidity']

createLinearRegressionPlot(x_values, y_values,"Latitude", "Humidity (%)", "Northern",(40, 20))

plt.savefig("Images/Northern_Hemisphere_Humidity_vs._Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.41
# The r-squared is: 0.17

# %% [markdown]
# #### The above plot is a linear regression model between Humidity (%) and Latitude for Northern Hemisphere cities. The result from the data showed that there is a moderate positive correlation between Humidity (%) and Latitude in the Northern Hemisphere cities.¶

# %% [markdown]
# #### Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs humidity (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Humidity']

createLinearRegressionPlot(x_values, y_values,"Latitude", "Humidity (%)", "Sorthern",(40, 20))

plt.savefig("Images/Southern_Hemisphere_Humidity_vs._Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.05
# The r-squared is: 0.0

# %% [markdown]
# #### The above plot is a linear regression model between Humidity (%) and Latitude for Southern Hemisphere cities. The result from the data showed that there is a very week positive correlation between Humidity (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# #### Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Northern",(30, 50))

plt.savefig("Images/Northern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.19
# The r-squared is: 0.04

# %% [markdown]
# #### The above plot is a linear regression model between Cloudiness (%) and Latitude for Northern_Hemisphere cities. The result from the data showed that there is a week positive correlation between Cloudiness (%) and Latitude in the Southern Hemisphere cities.

# %% [markdown]
# #### Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs cloudiness (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Cloudiness']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Cloudiness(%)", "Southern",(-45, 60))
plt.savefig("Images/Southern_Hemisphere_Cloudiness_Latitude_Linear.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.32
# The r-squared is: 0.1

# %% [markdown]
# #### The above plot is a linear regression model between Cloudiness (%) and for Southern Hemisphere cities. The result from the data showed that there is a week positive correlation between Cloudiness (%) and Latitude in the Southern Hemisphere cities.¶

# %% [markdown]
# #### Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed(northern hemisphere)
x_values = northern_hemisphere['Latitude']
y_values = northern_hemisphere['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Northern",(20, 25))
plt.savefig("Images/Northern_Hemisphere_Wind_Speed_Latitude_Lin.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : 0.15
# The r-squared is: 0.02

# %% [markdown]
# #### The above plot is a linear regression model between Wind Speed (mph), and latitude for Northern Hemisphere cities. The result from the data showed that there is a very week positive correlation between Wind Speed (mph (%) and Latitude in the Northern Hemisphere cities.

# %% [markdown]
# #### Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a scatter plot for latitude vs wind speed (southern hemisphere)
x_values = southern_hemisphere['Latitude']
y_values = southern_hemisphere['Wind Speed']
createLinearRegressionPlot(x_values, y_values, "Latitude", "Wind Speed (mph)", "Southern",(-40, 25))
plt.savefig("Images/Southern_Hemisphere_Wind_Speed_Latitude_Linear_Regression.png", bbox_inches="tight")
plt.show()
# Out:
# The correlation between both factors is : -0.07
# The r-squared is: 0.0

# %% [markdown]
# #### The above plot is a linear regression model between Wind Speed (mph), and latitude for Southern Hemisphere. The result from the data showed that there is a very week negative correlation between Wind Speed (mph (%) and Latitude in the Northern Hemisphere cities.
